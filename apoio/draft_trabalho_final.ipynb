# %% [markdown]
# ------------------------------
# # <center> <img alt="Colaboratory logo" width="15%" src="https://www.mackenzie.br/fileadmin/_processed_/4/2/csm_instituto-logo_4594b3b3ab.jpg"> </center>
#
#
#
# # <center> Data Science Experience </center>
#  ------------------------------
#
# # <center> TechCorpBrasil - Análise Exploratória </center>
#
# **📋Curso:** MBA em Engenharia de Dados  | **Turma:** 2025G
#
#
# **📋Grupo:**
#
# - Brunno Souza de Mambro Santos  (10740187)
# - Fábio Fumio Wada  (10741479)
# - Sweeli Suzuki (10423319)
# - Tatiane Silva Santos  (10747108)
#
# #
# #
#
# ------------------------------

# %% [markdown]
# # 📊 Dicionário de Dados - HR Analytics
#
# ## 📋 Informações Gerais do Dataset
#
# | **Propriedade** | **Valor** |
# |-----------------|-----------|
# | **Nome do Dataset** | IBM HR Analytics |
# | **Número de Registros** | 1,000,000 |
# | **Número de Features** | 23 |
# | **Variável Alvo** | Attrition (Yes/No) |
# | **Taxa de Attrition** | ~16% |
# | **Tipo de Problema** | Employee Attrition |

# %% [markdown]
# # <center> 📋 ** Análise Exploratória (2 pontos) </center>
#
# ## 📋 ** Análise estatística completa das variáveis
#
# ### 🔍 Python - Bibliotecas
#
# | **Nome da Biblioteca** | **Instalação Google Colab** | **Instalação Python** |
# |-----------|----------|---------------|
# | **Pandas** | !pip install pandas | pip install pandas |
# | **Numpy** | !pip install numpy | pip install numpy |
# | **Openpyx** | !pip install pandas openpyxl | pip install pandas openpyxl |
# | **Matplotlib** | !pip install matplotlib | pip install matplotlib |
#
# ### 🔍 Descrição das Variáveis
#
# ### 1. Variáveis Demográficas
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **Age** | Integer | Idade do funcionário | 18-65 | Média de 41 anos de idade |
# | **Gender** | String | Gênero do funcionário | 'Male', 'Female' | 50% Masculino e 49% Feminino |
# | **MaritalStatus** | String | Estado civil | 'Single', 'Married', 'Divorced' | Média de 33% para cada situação |
# | **Education** | String | Nível de educação | 'Bellow’ College', 'College', 'Bachelor','Master','Doctor' |
# | **EducationField** | String | Área de formação | ‘Information Tecnnology’, ‘Engineering’, ‘Marketing’, ‘Computer Science’, ‘Human Resources’, ‘Other’ | |
#
#
# ### 2. Variáveis Profissionais
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **Department** | String | Departamento atual | 'Sales', 'Research & Development', 'Human Resources' | **R&D tem maior população |
# | **JobRole** | String | Função/Cargo atual | 9 diferentes roles | Sales Executive', 'Software Developer', 'Project Manager', 'Financial Analyst', 'Director', 'Manager','Consultant', 'Analyst', 'Human Resources' |
# | **JobLevel** | Integer | Nível hierárquico | 1-5 | 1=Entry, 5=Senior |
# | **JobInvolvement** | Integer | Nível de envolvimento no trabalho | 1-4 | 1='Low', 2='Medium', 3='High', 4='Very High' |
# | **YearsAtCompany** | Integer | Anos na empresa atual | 0-40 | Média de 19 anos de tempo de empresa |
#
#
# ### 3. Variáveis de Compensação
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **MonthlyIncome** | Integer | Salário mensal | 1009-19999 | Média de 10500.00 de salário mensal |
# | **PercentSalaryHike** | Integer | % do último aumento | 11-25 | |
# | **StockOptionLevel** | Integer | Nível de stock options | 0-3 | 0=Sem opções, 3=Mais opções |
#
# ### 4. Variáveis de Satisfação
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **JobSatisfaction** | Integer | Satisfação com trabalho | 1-4 | 1='Low', 2='Medium', 3='High', 4='Very High' |
# | **EnvironmentSatisfaction** | Integer | Satisfação com ambiente | 1-4 | 1='Low', 2='Medium', 3='High', 4='Very High' |
# | **RelationshipSatisfaction** | Integer | Satisfação com relacionamentos | 1-4 | 1='Low', 2='Medium', 3='High', 4='Very High' |
#
#
# ### 5. Variáveis de Trabalho Atual (Work Life)
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **OverTime** | String | Realiza Horas Extras | 'Yes', 'No' | 28% dos funcionários praticam overtime |
# | **WorkLifeBalance** | Integer | Equilíbrio trabalho-vida | 1-4 | 1='Bad', 2='Good', 3='Better', 4='Best' |
# | **BusinessTravel** | String | Frequência de viagens | 'Non-Travel', 'Travel_Rarely', 'Travel_Frequently' | Média de 33% para cada situação|
# | **DistanceFromHome** | Integer | Distância casa-trabalho (km) | 1-29 | Média de 15km de distância |
#
# ### 6. Variáveis de Performance
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **PerformanceRating** | Integer | Avaliação de performance | 3-4 | 3='Excellent', 4='Outstanding' |
# | **TrainingTimesLastYear** | Integer | Treinamentos no último ano | 0-6 |  |
#
# ### 7. Variáveis de Target
#
# | **Campo** | **Tipo** | **Descrição** | **Valores** | **Observações** |
# |-----------|----------|---------------|-------------|-----------------|
# | **Attrition** | String | Funcionário deixou a empresa | 'Yes', 'No' | 16% - 'Yes' / 84% - No |
#
# ## 📋 ** Identificação de padrões e correlações
#
#     **📋Analisando o cenário atual (pó-geração do Dataset)**
#
# ### Fatores-chave que influenciam a rotatividade de funcionários (Attrition)
#
# A análise a seguir destaca as variáveis com maior impacto negativo na retenção de funcionários, ou seja, aquelas que contribuem para o aumento do *attrition*. Identificar esses pontos é o primeiro passo para desenvolver estratégias eficazes de mitigação.
#
#
# | **Variável** | **Correlação** | **Insight e Potencial Ação** |
# |--------------|----------------|------------------------------|
# | **OverTime** | Negativa | Funcionários com hora extra têm maior *attrition*. **Sugestão:** Revisar a carga de trabalho e a distribuição de tarefas. |
# | **JobSatisfaction** | Negativa | Menor satisfação = maior *attrition*. **Sugestão:** Implementar pesquisas de clima, programas de bem-estar e feedback contínuo. |
# | **Age** | Negativa | Funcionários mais jovens têm maior *attrition*. **Sugestão:** Desenvolver programas de mentoria e desenvolvimento de carreira para jovens talentos. |
# | **YearsAtCompany** | Negativa | Menos tempo na empresa = maior *attrition*. **Sugestão:** Fortalecer o processo de onboarding e programas de engajamento nos primeiros anos. |
# | **MonthlyIncome** | Negativa | Salários menores = maior *attrition*. **Sugestão:** Avaliar a competitividade salarial e estrutura de remuneração. |
# | **DistanceFromHome** | Negativa | Maior distância = maior *attrition*. **Sugestão:** Considerar modelos de trabalho flexíveis (híbrido/remoto) ou auxílios de transporte. |
# | **BusinessTravel** | Negativa | Mais viagem = maior *attrition*. **Sugestão:** Otimizar a necessidade de viagens e oferecer suporte adequado aos viajantes. |
# | **MaritalStatus** | Negativa | Estado Civil afeta o *attrition*. **Sugestão:** Entender as necessidades específicas de cada grupo e oferecer benefícios adaptados. |
#
#
# ### Variável Attrition
#
# | **Desligou-se da empresa** | **Quantidade** | **Percentual** |
# |--------------|----------------|-------------|
# | **No** | 839970 | 84% |
# | **Yes** |160030 | 16% |
#
# ### 🚨 Considerações para Modelagem
#
# ### Tratamento de Variáveis Categóricas
# - **One-Hot Encoding**: Department, EducationField, JobRole, MaritalStatus, Gender
# - **Label Encoding**: BusinessTravel, OverTime (binárias ordenadas)
# - **Manter como numérica**: Education, JobLevel (ordinais)

# %% [markdown]
# ## <center> 📋 Análise Técnica - Código Fonte </center>

# %% [markdown]
# **📋Bibliotecas Python**

# %%
#Versão 2.0

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("======================================================")
print("Etapa: Bibliotecas Python")
print("Bibliotecas carregadas: Pandas, Numpy, Matplotlib")
print("======================================================")
# Out:
# ...
# Etapa: Bibliotecas Python
# Bibliotecas carregadas: Pandas, Numpy, Matplotlib
# ...

# %% [markdown]
# ###![image.png](attachment:image.png)

# %%
# Gerando a amostra aleatória (gerador de números aleatórios com um valor específico), garantindo que os resultados "aleatórios" gerados posteriormente
# sejam reproduzíveis. Isso é essencial para testes, depuração e experimentos científicos onde a consistência dos resultados é importante.
# Se você executar esse código várias vezes, sempre obterá os mesmos números. Se mudar a semente (ex: np.random.seed(123)), a sequência será diferente.
# "The Hitchhiker's Guide to the Galaxy" (O Guia do Mochileiro das Galáxias), de Douglas Adams. Na história, um supercomputador chamado Deep Thought passa milhões de anos calculando a "Resposta para a Vida, o Universo e Tudo Mais" e, no final, a resposta é... 42."
# Para este exemplo, vou criar um dataset sintético similar - 
np.random.seed(42)

# Criando dataset sintético para demonstração
# Definindo o número de amostras através do parâmetro n_samples do numpy
n_samples = 1000000

v_employes_data = {
    #Variáveis Demográficas
    'Age': np.random.randint(18, 65, n_samples),
    'Gender': np.random.choice(['Female', 'Male'], n_samples),
    'MaritalStatus': np.random.choice(['Single', 'Married', 'Divorced'], n_samples),
    'Education': np.random.choice(['Bellow College', 'College', 'Bachelor','Master','Doctor'], n_samples),
    'EducationField': np.random.choice(['Information Technology', 'Other', 'Engineering', 'Marketing', 'Computer Science', 'Human Resources'], n_samples),
    #Variáveis Profissionais
    'Department': np.random.choice(['Sales', 'Research & Development', 'Human Resources'], n_samples),
    'JobRole': np.random.choice(['Sales Executive', 'Software Developer', 'Project Manager',
                                'Financial Analyst', 'Director', 'Manager',
                                'Consultant', 'Analyst', 'Human Resources'], n_samples),
        #    'JobRole': np.random.choice(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
        #                        'Manufacturing Director', 'Healthcare Representative', 'Manager',
        #                        'Sales Representative', 'Research Director', 'Human Resources'], n_samples),
    'JobLevel': np.random.randint(1, 6, n_samples),
    'JobInvolvement': np.random.randint(1, 5, n_samples),
    'YearsAtCompany': np.random.randint(0, 40, n_samples),
    #Variáveis de Compensação
    'MonthlyIncome': np.random.randint(1000, 20000, n_samples),
    'PercentSalaryHike': np.random.randint(11, 26, n_samples),
    'StockOptionLevel': np.random.randint(0, 4, n_samples),
    #Variáveis de Satisfação
    'JobSatisfaction': np.random.randint(1, 5, n_samples),
    'EnvironmentSatisfaction': np.random.randint(1, 5, n_samples),
    'RelationshipSatisfaction': np.random.randint(1, 5, n_samples),
    #Variáveis de Trabalho Atual (WorkLife)
    'OverTime': np.random.choice(['Yes', 'No'], n_samples, p=[0.28, 0.72]),
    'WorkLifeBalance': np.random.randint(1, 5, n_samples),
    'BusinessTravel': np.random.choice(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], n_samples),
    'DistanceFromHome': np.random.randint(1, 30, n_samples),
    #Variáveis de Performance
    'PerformanceRating': np.random.choice([3, 4], n_samples, p=[0.84, 0.16]),
    'TrainingTimesLastYear': np.random.randint(0, 7, n_samples),
    #Variáveis de Target
    'Attrition': np.random.choice(['Yes', 'No'], n_samples, p=[0.16, 0.84])
}

# gerando o dataframe através dos dados dos funcionários
df_dataset_employess = pd.DataFrame(v_employes_data)

print("======================================================")
print("Etapa: Definindo o Dataset")
print(f"Dataset de Empregados criado (df_dataset_employess) - Tamanho: {df_dataset_employess.shape[0]} linhas, {df_dataset_employess.shape[1]} colunas")
print("======================================================")
# Out:
# ...
# Etapa: Definindo o Dataset
# Dataset de Empregados criado (df_dataset_employess) - Tamanho: 1000000 linhas, 23 colunas
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Analisando o cenário atual

# Analisando variáveis que fazem correlação com a variável target 'Attrition'

############################################################################################
# 1. Obter as contagens
############################################################################################
v_overtime_cenario_atual = df_dataset_employess['OverTime'].value_counts()
v_jobasatisfaction_cenario_atual = df_dataset_employess['JobSatisfaction'].value_counts()
v_age_cenario_atual = df_dataset_employess['Age'].value_counts()
v_yearsatcompany_cenario_atual = df_dataset_employess['YearsAtCompany'].value_counts()
v_monthlyincome_cenario_atual = df_dataset_employess['MonthlyIncome'].value_counts()
v_distancefromhome_cenario_atual = df_dataset_employess['DistanceFromHome'].value_counts()
v_bussinesstravel_cenario_atual = df_dataset_employess['BusinessTravel'].value_counts()
v_maritalstatus_cenario_atual = df_dataset_employess['MaritalStatus'].value_counts()

############################################################################################
# 2. Gerar o gráfico de pizza
############################################################################################
plt.figure(figsize=(3, 3)) # Define o tamanho do gráfico para melhor visualização

##### Overtime
v_overtime_cenario_atual.plot.pie(autopct='%1.1f%%', startangle=90) 
plt.title('Overtime (Cenário Atual)')
plt.ylabel('') 
print("\033[1m===================================.\033[0m")
print("\033[1mAnálise do cenário atual (Overtime).\033[0m")
print("\033[1m===================================.\033[0m")
plt.show() 

##### JobSatisfaction
v_jobasatisfaction_labels = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
v_jobasatisfaction_labels_grafico = [v_jobasatisfaction_labels[i] for i in v_jobasatisfaction_cenario_atual.index]
v_jobasatisfaction_cenario_atual.plot.pie(autopct='%1.1f%%', startangle=90, labels=v_jobasatisfaction_labels_grafico) 
plt.title('Satisfaction (Cenário Atual)') 
plt.ylabel('') 
print("\033[1m==========================================.\033[0m")
print("\033[1mAnálise do cenário atual (JobSatisfaction).\033[0m")
print("\033[1m==========================================.\033[0m")
plt.show() 

##### Age
# Calculando as estatísticas de idade
v_age_min = df_dataset_employess['Age'].min()
v_age_max = df_dataset_employess['Age'].max()
v_age_mean = df_dataset_employess['Age'].mean()

# DataFrame para armazenar as estatísticas de idade
v_age_estatisticas = pd.DataFrame({
    'Metric': ['Min', 'Mean', 'Max'],
    'Age': [v_age_min, v_age_mean, v_age_max]
})

# Gerando o gráfico de barras
plt.figure(figsize=(3, 3))
plt.bar(v_age_estatisticas['Metric'], v_age_estatisticas['Age'], color=['skyblue', 'lightgreen', 'salmon'])

for index, value in enumerate(v_age_estatisticas['Age']):
    plt.text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom') 

plt.title('Minimum, Average and Maximum Age of Employees') 
plt.xlabel('Métric') 
plt.ylabel('Age') 
plt.ylim(0, v_age_max * 1.1) 
plt.grid(axis='y', linestyle='--', alpha=0.7) 
print("\033[1m==============================.\033[0m")
print("\033[1mAnálise do cenário atual (Age).\033[0m")
print("\033[1m==============================.\033[0m")
plt.show() 

##### YearsAtCompany
# Calculando as estatísticas do tempo de empresa
v_yearscompany_min = df_dataset_employess['YearsAtCompany'].min()
v_yearscompany_max = df_dataset_employess['YearsAtCompany'].max()
v_yearscompany_mean = df_dataset_employess['YearsAtCompany'].mean()    

# DataFrame para armazenar as estatísticas de idade
v_yearscompany_estatisticas = pd.DataFrame({
    'Metric': ['Min', 'Mean', 'Max'],
    'Years': [v_yearscompany_min, v_yearscompany_mean, v_yearscompany_max]
})

# Gerando o gráfico de barras
plt.figure(figsize=(3, 3)) 
plt.bar(v_yearscompany_estatisticas['Metric'], v_yearscompany_estatisticas['Years'], color=['skyblue', 'lightgreen', 'salmon'])

for index, value in enumerate(v_yearscompany_estatisticas['Years']):
    plt.text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom') 

plt.title('Minimum, Average and Maximum Years at Company') 
plt.xlabel('Métric') 
plt.ylabel('Age') 
plt.ylim(0, v_yearscompany_max * 1.1) 
plt.grid(axis='y', linestyle='--', alpha=0.7) 
print("\033[1m=========================================.\033[0m")
print("\033[1mAnálise do cenário atual (YearsAtCompany).\033[0m")
print("\033[1m=========================================.\033[0m")
plt.show() 

##### MonthlyIncome
# Calculando as estatísticas de renda mensal
v_monthlyincome_min = df_dataset_employess['MonthlyIncome'].min()
v_monthlyincome_max = df_dataset_employess['MonthlyIncome'].max()
v_monthlyincome_mean = df_dataset_employess['MonthlyIncome'].mean()    

# DataFrame para armazenar as estatísticas de renda mensais
v_monthlyincome_estatisticas = pd.DataFrame({
    'Metric': ['Min', 'Mean', 'Max'],
    'Income': [v_monthlyincome_min, v_monthlyincome_mean, v_monthlyincome_max]
})

# Gerando o gráfico de barras
plt.figure(figsize=(8, 5)) 
plt.barh(v_monthlyincome_estatisticas['Metric'],
         v_monthlyincome_estatisticas['Income'],
         color=['skyblue', 'lightgreen', 'salmon'])

for index, value in enumerate(v_monthlyincome_estatisticas['Income']):
    plt.text(value + (v_monthlyincome_max * 0.02),
             index,                                
             f'{value:.2f}',
             ha='left',                           
             va='center')                         

plt.title('Minimum, Average and Maximum of Income')
plt.xlabel('Income')
plt.ylabel('Metric')
plt.xlim(0, v_monthlyincome_max * 1.1)
plt.grid(axis='x', linestyle='--', alpha=0.7)
print("\033[1m========================================.\033[0m")
print("\033[1mAnálise do cenário atual (MonthlyIncome).\033[0m")
print("\033[1m========================================.\033[0m")
plt.show()

##### DistanceFromHome
# Calculando as estatísticas de distância de casa   
v_distancefromhome_min = df_dataset_employess['DistanceFromHome'].min()
v_distancefromhome_max = df_dataset_employess['DistanceFromHome'].max()
v_distancefromhome_mean = df_dataset_employess['DistanceFromHome'].mean()    

# DataFrame para armazenar as estatísticas de renda mensais
v_distancefromhome_estatisticas = pd.DataFrame({
    'Metric': ['Min', 'Mean', 'Max'],
    'Distance': [v_distancefromhome_min, v_distancefromhome_mean, v_distancefromhome_max]
})

# Gerando o gráfico de barras
plt.figure(figsize=(3, 3)) 
plt.bar(v_distancefromhome_estatisticas['Metric'], v_distancefromhome_estatisticas['Distance'], color=['skyblue', 'lightgreen', 'salmon'])

for index, value in enumerate(v_distancefromhome_estatisticas['Distance']):
    plt.text(index, value + 0.5, f'{value:.2f}', ha='center', va='bottom') 

plt.title('Minimum, Average and Maximum at distance from home') 
plt.xlabel('Métric') 
plt.ylabel('Distance') 
plt.ylim(0, v_distancefromhome_max * 1.1) 
plt.grid(axis='y', linestyle='--', alpha=0.7) 
print("\033[1m===========================================.\033[0m")
print("\033[1mAnálise do cenário atual (DistanceFromHome).\033[0m")
print("\033[1m===========================================.\033[0m")
plt.show() 

##### BussinessTravel
# Obtendo as contagens de viagens de negócios
v_bussinesstravel_cenario_atual.plot.pie(autopct='%1.1f%%', startangle=90) 
plt.title('BussinessTravel (Cenário Atual)')
plt.ylabel('') 
print("\033[1m==========================================.\033[0m")
print("\033[1mAnálise do cenário atual (BussinessTravel).\033[0m")
print("\033[1m==========================================.\033[0m")
plt.show() 

##### MaritalStatus
# Obtendo as contagens de estado civil  
v_maritalstatus_cenario_atual.plot.pie(autopct='%1.1f%%', startangle=90) 
plt.title('MaritalStatus (Cenário Atual)')
plt.ylabel('') 
print("\033[1m========================================.\033[0m")
print("\033[1mAnálise do cenário atual (MaritalStatus).\033[0m")
print("\033[1m========================================.\033[0m")
plt.show()

# %%
#Exportando daframe para o excel

#df_dataset_employess.to_excel('dataset_employess.xlsx', index=False) 
#9minutos e 11.9 segundos para gerar 1.000.000 de linhas

# %%
#df_dataset_employess.describe(include='all')
#df_dataset_employess['Attrition']
#df_dataset_employess['Gender'].value_counts()
df_dataset_employess.describe()
#

#df_dataset_employess['Attrition'].value_counts()

# %%
v_nome_campo = 'Gender'
min_valor = df_dataset_employess[v_nome_campo].min()
max_valor = df_dataset_employess[v_nome_campo].max()
media_valor = df_dataset_employess[v_nome_campo].mean() 

print(min_valor)
print(max_valor)
print(media_valor)
